# %%
import pandas as pd
import numpy as np

print("I libraries imported succesfully.")
# Out:
# I libraries imported succesfully.

# %%
df=pd.read_csv(r"C:\Users\HomePC\Downloads\Salary Data - Form Responses 1.csv")
print("data loaded succesfully.")

rows, cols = df.shape
print(f"Rows: {rows}, Columns: {cols}")
# Out:
# data loaded succesfully.
# Rows: 28223, Columns: 18

# %%
print(df.head())
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
print(f"Colums : {df.columns.tolist()}")
# Out:
# Colums : ['Timestamp', 'How old are you?', 'What industry do you work in?', 'Job title', 'If your job title needs additional context, please clarify here:', "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)", 'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.', 'Please indicate the currency', 'If "Other," please indicate the currency here: ', 'If your income needs additional context, please provide it here:', 'What country do you work in?', "If you're in the U.S., what state do you work in?", 'What city do you work in?', 'How many years of professional work experience do you have overall?', 'How many years of professional work experience do you have in your field?', 'W
# ...

# %%
missing_values= df.isnull().sum().sum()
print(missing_values)
# Out:
# 87351

# %%
missing_values= df.isnull().sum()
print(missing_values)
# Out:
# Timestamp                                                                                                                                                                                                                                   0
# How old are you?                                                                                                                                                                                                                            0
# What industry do you work in?                                                                                                                                                                                                              86
# Job title                                                                                                                                                                                                                                   5
# ...

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'How old are you?', 'What industry do you work in?', 'Job title', 'If your job title needs additional context, please clarify here:', "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)", 'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.', 'Please indicate the currency', 'If "Other," please indicate the currency here:', 'If your income needs additional context, please provide it here:', 'What country do you work in?', "If you're in the U.S., what state do you work in?", 'What city do you work in?', 'How many years of professional work experience do you have overall?', 'How many years of professional work experience do you have in your field?', 'What is you
# ...

# %%
df.columns = ['Timestamp','Age_group','Industry','Job','Job_specification','Annual_salary','Salary_bonus','Salary_currency','Alternative_currency','Income_info','Country','US_state','City','Overall_working_experience','Current_working_experience','Education_level','Gender','Race']

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'Age_group', 'Industry', 'Job', 'Job_specification', 'Annual_salary', 'Salary_bonus', 'Salary_currency', 'Alternative_currency', 'Income_info', 'Country', 'US_state', 'City', 'Overall_working_experience', 'Current_working_experience', 'Education_level', 'Gender', 'Race']

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Timestamp                         0
# Age_group                         0
# Industry                         86
# Job                               5
# Job_specification             20930
# Annual_salary                     0
# Salary_bonus                   7374
# Salary_currency                   0
# Alternative_currency          27999
# Income_info                   25170
# Country                           2
# US_state                       5076
# City                             85
# Overall_working_experience        0
# Current_working_experience        0
# Education_level                 241
# Gender                          186
# Race                            197
# dtype: int64

# %%
df.describe()
# Out:
#        Salary_bonus
# count  2.084900e+04
# mean   1.822120e+04
# std    8.325053e+05
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    2.000000e+03
# 75%    1.000000e+04
# max    1.200000e+08
